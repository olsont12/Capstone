# %%
import pandas as pd

# %% [markdown]
# ## Scraping spring migration create dataframe

# %%
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2020&season=spring")
spring2020 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2019&season=spring")
spring2019 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2018&season=spring")
spring2018 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2017&season=spring")
spring2017 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2016&season=spring")
spring2016 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2015&season=spring")
spring2015 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2014&season=spring")
spring2014 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2013&season=spring")
spring2013 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2012&season=spring")
spring2012 = spring[0]
spring = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-adult-first&year=2011&season=spring")
spring2011 = spring[0]

# %%
spring_final_df = spring2020.append([spring2019, spring2018, spring2017,spring2016, spring2015, spring2014, spring2013, spring2012, spring2011])

# %%
spring_final_df['Number'] = spring_final_df['Number'].fillna(1)

# %%
spring_final_df['Butterfly_Sighted']='Butterfly_Sighted'

# %%
spring_final_df.to_csv("C:/Users/t_d_o/Documents/capstone/spring_final_df.csv")

# %%
spring_final_df
# Out:
#       Unnamed: 0      Date              Town State/Province  Latitude  \
# 0              1  06/14/20        Huntington             IN      40.9
# 1              2  06/14/20        Lehman Twp             PA      41.3
# 2              3  06/14/20         Ostrander             OH      40.3
# 3              4  06/14/20         Sifton RM             MB      49.7
# 4              5  06/14/20     South Windsor             CT      41.8
# ...          ...       ...               ...            ...       ...
# 1141        1142  02/28/11            Boerne             TX      29.8
# 1142        1143  02/28/11            Santee             CA      32.9
# 1143        1144  02/27/11      Ramos Arizpe            COA      25.6
# 1144        1145  02/22/11  Saint Petersburg             FL      27.8
# 1145        1146  02/20/11  Saint Petersburg             FL      27.8
#
#       Longitude  Number  Image  Butterfly_Sighted
# 0         -85.5     1.0    NaN  Butterfly_Sighted
# ...

# %% [markdown]
# ### Getting Californa Population Numbers

# %%
California = pd.read_html("https://www.experiencepismobeach.com/beach-and-outdoors/monarch-butterflies/monarch-grove/historical-counts/")
California_df0 = California[0]
California = pd.read_html("https://www.experiencepismobeach.com/beach-and-outdoors/monarch-butterflies/monarch-grove/historical-counts/")
California_df1 = California[1]
California = pd.read_html("https://www.experiencepismobeach.com/beach-and-outdoors/monarch-butterflies/monarch-grove/historical-counts/")
California_df2 = California[2]
California = pd.read_html("https://www.experiencepismobeach.com/beach-and-outdoors/monarch-butterflies/monarch-grove/historical-counts/")
California_df3 = California[3]

# %%
California_df = California_df0.append([California_df1, California_df2, California_df3])
# Out:
#                      0
# 0  1990-1991 – 230,000
# 1  1991-1992 – 175,000
# 2   1992-1993 – 20,000
# 3   1993-1994 – 35,000
# 4   1994-1995 – 15,000
# 5  1995-1996 – 150,000
# 6   1996-1997 – 50,000
# 0  1997-1998 – 110,000
# 1  1998-1999 – 115,000
# 2   1999-2000 – 60,000
# 3   2000-2001 – 40,000
# 4   2001-2002 – 60,000
# 5  2002-2003 – 130,000
# 6   2003-2004 – 56,000
# 0   2004-2005 – 35,000
# 1   2005-2006 – 23,000
# 2   2006-2007 – 22,000
# 3   2007-2008 – 17,000
# 4   2008-2009 – 28,500
# 5   2009-2010 – 17,000
# 6   2010-2011 – 24,000
# 0   2011-2012 – 23,050
# 1   2012-2013 – 28,000
# 2   2013-2014 – 34,000
# 3   2014-2015 – 31,100
# 4   2015-2016 – 28,000
# 5   2016-2017 – 28,000
# 6   2017-2018 – 12,075
# 7    2018-2019 – 3,077

# %%
California_df.columns = ['Count']

# %%
California_df['Year'] = California_df['Count'].str[:9]
California_df['Count'] = California_df['Count'].str[12:]

# %%
California_df.to_csv("C:/Users/t_d_o/Documents/capstone/California_df.csv")

# %% [markdown]
# ## Scraping over wintering data adding 2 rows from current data from WWF

# %%
overwintering = pd.read_html("https://www.fws.gov/midwest/monarch/OverwinteringMonarchs.html")
overwintering = overwintering[0]
overwintering.loc[25] = [2018, 14.9]
overwintering.loc[26] = [2019, 6.99]

# %%
overwintering.columns = ['Year (data collected during December)', 'Total Area Covered (Acres)']

# %%
overwintering['Population in Millons'] = round(overwintering['Total Area Covered (Acres)'] * 20.26, 2)

# %%
overwintering = overwintering.melt(
    id_vars=['Year (data collected during December)'],
    var_name='Category',
    value_name='Metric'
)

# %%
overwintering.to_csv("C:/Users/t_d_o/Documents/capstone/overwintering.csv")

# %% [markdown]
# ## Scraping fall migration create dataframe

# %%
overwintering.to_csv("C:/Users/t_d_o/Documents/capstone/overwinteringdf.csv")

# %%
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2019&season=fall")
fall2019 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2018&season=fall")
fall2018 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2017&season=fall")
fall2017 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2016&season=fall")
fall2016 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2015&season=fall")
fall2015 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2014&season=fall")
fall2014 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2013&season=fall")
fall2013 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2012&season=fall")
fall2012 = fall[0]
fall = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=monarch-peak-migration&year=2011&season=fall")
fall2011 = fall[0]

# %%
fall_final_df = fall2019.append([fall2018, fall2017,fall2016, fall2015, fall2014, fall2013, fall2012, fall2011])

# %%
fall_final_df['Number'] = fall_final_df['Number'].fillna(1)

# %%
fall_final_df['Butterfly_Sighted']='Butterfly_Sighted'

# %%
fall_final_df.to_csv("C:/Users/t_d_o/Documents/capstone/fall_final_df.csv")

# %%
fall_final_df
# Out:
#      Unnamed: 0      Date          Town       State/Province  Latitude  \
# 0             1  11/15/19     Zitácuaro  Michoacán de Ocampo      19.4
# 1             2  11/13/19      Contepec  Michoacán de Ocampo      19.9
# 2             3  11/11/19    Brownsboro                   TX      32.3
# 3             4  11/11/19     Monterrey                  NLE      25.6
# 4             5  11/10/19      Fairhope                   AL      30.5
# ..          ...       ...           ...                  ...       ...
# 385         386  08/29/11       chicago                   IL      41.9
# 386         387  08/28/11  New Richmond                   WI      45.2
# 387         388  08/27/11      Winnetka                   IL      42.1
# 388         389  08/26/11  New Richmond                   WI      45.2
# 389         390  08/26/11       Shawano                   WI      44.9
#
#      Longitude  Number  Image  Butterfly_Sighted
# 0       -100.3   300.0    NaN  Butterfly_Sighted
# ...

# %% [markdown]
# ## Combining Spring, Milkweed and fall data frames

# %%
combined_final_df = fall_final_df.append([spring_final_df])

# %%
combined_final_df = milkweed_df.append([spring_final_df, fall_final_df])

# %%
combined_final_df.to_csv("C:/Users/t_d_o/Documents/capstone/combined_final_df.csv")
# Out:
#       Unnamed: 0      Date              Town State/Province  Latitude  \
# 0              1  06/12/20       Beach Haven             NJ      39.7
# 1              2  06/12/20             Gomer             OH      40.8
# 2              3  06/12/20           Keyport             NJ      40.4
# 3              4  06/12/20      Libertyville             IL      42.3
# 4              5  06/12/20            Morris             MB      49.4
# ...          ...       ...               ...            ...       ...
# 1141        1142  02/28/11            Boerne             TX      29.8
# 1142        1143  02/28/11            Santee             CA      32.9
# 1143        1144  02/27/11      Ramos Arizpe            COA      25.6
# 1144        1145  02/22/11  Saint Petersburg             FL      27.8
# 1145        1146  02/20/11  Saint Petersburg             FL      27.8
#
#       Longitude  Number  Image
# 0         -74.1     1.0    NaN
# 1         -84.2     1.0    NaN
# ...

# %% [markdown]
# ### earliest by state data

# %%
earliest_by_state = spring_final_df[spring_final_df.groupby('State/Province').Date.transform('min') == spring_final_df['Date']]

# %%
earliest_by_state.to_csv("C:/Users/t_d_o/Documents/capstone/earliest_by_state.csv")

# %%
earliest_by_state
# Out:
#       Unnamed: 0      Date              Town State/Province  Latitude  \
# 268          269  06/03/20            Nibley           Utah      41.7
# 323          324  06/02/20          Sheridan             WY      44.8
# 1195        1196  05/15/20           Kelowna             BC      49.9
# 1443        1444  04/26/20    North Branford             CT      41.3
# 1628        1629  04/08/20          Columbia             MD      39.2
# ...          ...       ...               ...            ...       ...
# 819          820  04/08/11             Tepic            NAY      21.5
# 832          833  04/07/11          Newburgh             IN      38.0
# 876          877  04/04/11              Atco             NJ      39.8
# 978          979  03/22/11    Gomez Palacios            DGO      25.6
# 1057        1058  03/15/11  Manuel Benavides            CHH      29.1
#
#       Longitude  Number  Image
# 268      -111.8     1.0    NaN
# 323      -107.0     1.0    NaN
# ...

# %% [markdown]
# ### Milkweed data

# %%
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2020&season=spring")
milkweed2020 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2019&season=spring")
milkweed2019 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2018&season=spring")
milkweed2018 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2017&season=spring")
milkweed2017 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2016&season=spring")
milkweed2016 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2015&season=spring")
milkweed2015 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2014&season=spring")
milkweed2014 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2013&season=spring")
milkweed2013 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2012&season=spring")
milkweed2012 = milkweed[0]
milkweed = pd.read_html("https://journeynorth.org/sightings/querylist.html?map=milkweed-first&year=2011&season=spring")
milkweed2011 = milkweed[0]

# %%
milkweed_df = milkweed2020.append([milkweed2019, milkweed2018, milkweed2017, milkweed2016, milkweed2015, milkweed2014, milkweed2013, milkweed2012, milkweed2011])

# %%
milkweed_df['Number'] = milkweed_df['Number'].fillna(1)

# %%
milkweed_df['Butterfly_Sighted']='Milkweed_Sighted'

# %%
milkweed_df.to_csv("C:/Users/t_d_o/Documents/capstone/milkweed_df.csv")

# %% [markdown]
# ### 3 Month Ave Temp Data

# %%
state_ave_temp = pd.read_csv('C:/Users/t_d_o/Documents/capstone/110-tavg-201205-3.csv', skiprows=3)

# %%
state_ave_temp.columns = ['Location ID', 'State', '3_Month_Ave_Temp', 'Rank', 'Anomaly', 'Mean']

# %%
state_ave_temp_df = state_ave_temp.melt(id_vars=['State'], 
              value_vars=['3_Month_Ave_Temp', 'Rank', 'Anomaly'],
              var_name='Variable', value_name='Value')

# %%
state_ave_temp_df.to_csv("C:/Users/t_d_o/Documents/capstone/state_ave_temp_df.csv")
